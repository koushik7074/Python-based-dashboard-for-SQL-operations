# %% [markdown]
# ### Import libraries

# %%
import pandas
import numpy
import os
from dotenv import load_dotenv
import mysql.connector

# %% [markdown]
# ### Database connection

# %%
# Load variables from .env
load_dotenv()

def connect_to_db():
    conn = mysql.connector.connect(
        host=os.getenv("DB_HOST"),
        user=os.getenv("DB_USER"),
        password=os.getenv("DB_PASSWORD"),
        database=os.getenv("DB_NAME")
    )
    return conn

# %%
connect_to_db().is_connected()
# Out:
# True

# %% [markdown]
# ### Defining an agnet "cursor" who will communicate with db

# %%
db = connect_to_db()
cursor = db.cursor(dictionary=True)

# %%
cursor.execute("select count(*) as cnt from products") #this is just execute query on MySQL but will not return anything here

# %%
row = cursor.fetchone()

# %%
row
# Out:
# {'cnt': 201}

# %%
list(row.values())[0]
# Out:
# 201

# %%
queries = {
    "Total Suppliers": "select count(*) as total_suppliers from suppliers;",

    "Total Products": "select count(*) as total_products from products;",

    "Total Categories Dealing": "select count(distinct category) as total_categories from products;",

    "Total Sale Value (last 3 months)": """ 
        select round(sum(abs(se.change_quantity) * p.price), 2) as total_sales_value_in_last_3_months
        from stock_entries as se
        join products as p 
        on p.product_id = se.product_id
        where se.change_type='Sale' and se.entry_date >= (select date_sub(max(entry_date), interval 3 month) from stock_entries);
        """,

    "Total Restock Value (last 3 months)": """ 
        select round(sum(abs(se.change_quantity) * p.price), 2) as total_restock_value_in_last_3_months
        from stock_entries as se
        join products as p 
        on p.product_id = se.product_id
        where se.change_type='Restock' and se.entry_date >= (select date_sub(max(entry_date), interval 3 month) from stock_entries);
        """,

    "Below Reorders and No Pending Reorders": """ 
        select count(*) from products as p where p.stock_quantity < p.reorder_level
        and product_id not in (
        select distinct product_id from reorders where status='Pending'
        )
        """
}

# %%
result={}

for label, query in queries.items():
    cursor.execute(query)
    row = cursor.fetchone()
    result[label] = list(row.values())[0]

# %%
result
# Out:
# {'Total Suppliers': 50,
#  'Total Products': 201,
#  'Total Categories Dealing': 5,
#  'Total Sale Value (last 3 months)': None,
#  'Total Restock Value (last 3 months)': 9999.0,
#  'Below Reorders and No Pending Reorders': 14}

# %%
def get_basic_info(cursor):
    queries = {
    "Total Suppliers": "select count(*) as total_suppliers from suppliers;",

    "Total Products": "select count(*) as total_products from products;",

    "Total Categories Dealing": "select count(distinct category) as total_categories from products;",

    "Total Sale Value (last 3 months)": """ 
        select round(sum(abs(se.change_quantity) * p.price), 2) as total_sales_value_in_last_3_months
        from stock_entries as se
        join products as p 
        on p.product_id = se.product_id
        where se.change_type='Sale' and se.entry_date >= (select date_sub(max(entry_date), interval 3 month) from stock_entries);
        """,

    "Total Restock Value (last 3 months)": """ 
        select round(sum(abs(se.change_quantity) * p.price), 2) as total_restock_value_in_last_3_months
        from stock_entries as se
        join products as p 
        on p.product_id = se.product_id
        where se.change_type='Restock' and se.entry_date >= (select date_sub(max(entry_date), interval 3 month) from stock_entries);
        """,

    "Below Reorders and No Pending Reorders": """ 
        select count(*) from products as p where p.stock_quantity < p.reorder_level
        and product_id not in (
        select distinct product_id from reorders where status='Pending'
        )
        """
    }

    result={}

    for label, query in queries.items():
        cursor.execute(query)
        row = cursor.fetchone()
        result[label] = list(row.values())[0]
    
    return result

# %%
queries = {
    "Suppliers contact details": "select supplier_name, contact_name, email, phone from suppliers;",

    "Product with suppliers and stock": """
    select p.product_name, s.supplier_name, p.stock_quantity, p.reorder_level
    from products as p
    join suppliers as s
    on p.supplier_id = s.supplier_id
    order by p.product_name;
    """,

    "Product needing reorder":""" 
    select product_id, product_name, stock_quantity, reorder_level
    from products 
    where stock_quantity < reorder_level
    """
}

# %%
table={}

for label, query in queries.items():
    cursor.execute(query)
    table[label] = cursor.fetchall()

# %%
table
# Out:
# {'Suppliers contact details': [{'supplier_name': 'Anderson-Thompson',
#    'contact_name': 'Bonnie Davis',
#    'email': 'zacharysanchez@hotmail.com',
#    'phone': '829.485.9853x0522'},
#   {'supplier_name': 'Rowland Ltd',
#    'contact_name': 'Beth Stevens',
#    'email': 'joshua60@yahoo.com',
#    'phone': '(779)942-0726'},
#   {'supplier_name': 'Baxter-Meadows',
#    'contact_name': 'Lisa Lewis',
#    'email': 'andersonchristina@yahoo.com',
#    'phone': '449-766-7325'},
#   {'supplier_name': 'Wilson, Graham and Williams',
#    'contact_name': 'David Martinez',
#    'email': 'abrown@hotmail.com',
#    'phone': '+1-653-827-5215x266'},
#   {'supplier_name': 'Smith, Kennedy and Moreno',
#    'contact_name': 'Victoria Gonzalez',
#    'email': 'mary30@williams-moore.com',
#    'phone': '891-859-2775x35297'},
#   {'supplier_name': 'Middleton LLC',
#    'contact_name': 'Megan Miller',
#    'email': 'kelseywilliams@gmail.com',
#    'phone': '001-724-731-6199x4596'},
#   {'supplier_name': 'Evans Inc',
#    'contact_name': 'Danielle Moore',
#    'email': 'ihoffman@warren.com',
#    'phone': '+1-951-447-1975x770'},
#   {'supplier_name': 'Lawrence, Garcia and Hernandez',
#    'contact_name': 'Tamara Johnson',
#    'email': 'georgeherrera@hotmail.com',
#    'phone': '+1-635-460-8476x270'},
#   {'supplier_name': 'Young, Browning and Ware',
#    'contact_name': 'Heather Hill',
#    'email': 'stephensjason@yahoo.com',
#    'phone': '(514)361-6411x489'},
#   {'supplier_name': 'Newton, Valencia and Carr',
#    'contact_name': 'Kimberly Collins',
#    'email': 'jonathanjohnston@ashley-williams.com',
#    'phone': '762-368-3504x8972'},
#   {'supplier_name': 'Vega, Cook and Miller',
#    'contact_name': 'Stephen Rogers',
#    'email': 'ianderson@thompson.com',
#    'phone': '(545)747-7182x90685'},
#   {'supplier_name': 'Mendoza-Jones',
#    'contact_name': 'Daniel Archer',
#    'email': 'clarketodd@bush-parker.com',
#    'phone': '077.020.6783x0807'},
#   {'supplier_name': 'Gallagher-Miller',
#    'contact_name': 'Michael Moore',
#    'email': 'jesse95@gmail.com',
#    'phone': '+1-462-260-2525x67365'},
#   {'supplier_name': 'Miller-Martinez',
#    'contact_name': 'Paula Morales',
#    'email': 'floresderek@yahoo.com',
#    'phone': '+1-700-794-1809x5862'},
#   {'supplier_name': 'Freeman-Gordon',
#    'contact_name': 'Zachary Garcia',
#    'email': 'angela33@humphrey.org',
#    'phone': '172-492-5671'},
#   {'supplier_name': 'Tucker-Arnold',
#    'contact_name': 'Katherine Lopez DVM',
#    'email': 'michelle03@hotmail.com',
#    'phone': '001-661-335-2179x4217'},
#   {'supplier_name': 'Gomez PLC',
#    'contact_name': 'James Fernandez',
#    'email': 'lovewarren@harris.info',
#    'phone': '661-353-3289'},
#   {'supplier_name': 'Moss-Evans',
#    'contact_name': 'Jennifer Green',
#    'email': 'crystalroth@yahoo.com',
#    'phone': '+1-877-605-7924x7393'},
#   {'supplier_name': 'Charles Inc',
#    'contact_name': 'Lori Liu',
#    'email': 'suzanne20@donaldson.net',
#    'phone': '+1-059-663-9297x67941'},
#   {'supplier_name': 'Ortega-Mahoney',
#    'contact_name': 'Teresa Miller',
#    'email': 'ile@hotmail.com',
#    'phone': '001-415-849-5736x81908'},
#   {'supplier_name': 'Mann-Marshall',
#    'contact_name': 'Scott Watts',
#    'email': 'colejoseph@hotmail.com',
#    'phone': '7317296630'},
#   {'supplier_name': 'Hudson Inc',
#    'contact_name': 'Michael Nguyen',
#    'email': 'ucochran@osborn.com',
#    'phone': '+1-563-056-3764x85079'},
#   {'supplier_name': 'Douglas Ltd',
#    'contact_name': 'Jonathan White',
#    'email': 'michael15@hotmail.com',
#    'phone': '001-734-858-5527x84897'},
#   {'supplier_name': 'Barker, White and Carson',
#    'contact_name': 'Cesar Moore',
#    'email': 'qhogan@yahoo.com',
#    'phone': '(521)673-3153x7796'},
#   {'supplier_name': 'Barrett Ltd',
#    'contact_name': 'Kim Wheeler',
#    'email': 'william52@hotmail.com',
#    'phone': '+1-887-075-4700'},
#   {'supplier_name': 'Tran LLC',
#    'contact_name': 'Anthony Jacobs',
#    'email': 'bdavis@fuller.com',
#    'phone': '(460)711-5746'},
#   {'supplier_name': 'Franklin, Kane and Price',
#    'contact_name': 'John Mueller',
#    'email': 'mitchellpierce@gmail.com',
#    'phone': '230.183.6177x07682'},
#   {'supplier_name': 'Stewart, Williams and Cox',
#    'contact_name': 'Nichole Fuller',
#    'email': 'mitchelllauren@hotmail.com',
#    'phone': '001-632-585-1111x529'},
#   {'supplier_name': 'Johnson-Bass',
#    'contact_name': 'Megan Carroll',
#    'email': 'fernandeztiffany@page.net',
#    'phone': '3531846182'},
#   {'supplier_name': 'Lloyd and Sons',
#    'contact_name': 'Sarah Ross',
#    'email': 'heathkaren@gmail.com',
#    'phone': '064-804-0646x199'},
#   {'supplier_name': 'Taylor-Love',
#    'contact_name': 'Daniel Mcgrath',
#    'email': 'perrykeith@kennedy.com',
#    'phone': '841-905-8982x711'},
#   {'supplier_name': 'Elliott-Ayers',
#    'contact_name': 'Kelly Avery',
#    'email': 'joseph44@moore-soto.biz',
#    'phone': '768-127-8200x348'},
#   {'supplier_name': 'Reynolds-Phillips',
#    'contact_name': 'Ashlee Montoya',
#    'email': 'stonewesley@bowen-salinas.biz',
#    'phone': '+1-869-461-6007x4674'},
#   {'supplier_name': 'Moody-Vang',
#    'contact_name': 'Joseph Peterson',
#    'email': 'hward@hotmail.com',
#    'phone': '001-530-230-6560x82908'},
#   {'supplier_name': 'Perez, Price and Wallace',
#    'contact_name': 'James Rich',
#    'email': 'natashapierce@knox.com',
#    'phone': '409.569.6703'},
#   {'supplier_name': 'Wong Group',
#    'contact_name': 'Lauren Humphrey',
#    'email': 'hayeseric@george.com',
#    'phone': '546-100-3064x5276'},
#   {'supplier_name': 'Kaufman Ltd',
#    'contact_name': 'Chelsea Young',
#    'email': 'wendy80@smith.net',
#    'phone': '(434)045-1867x11846'},
#   {'supplier_name': 'Harris-Cummings',
#    'contact_name': 'Jonathan Foley',
#    'email': 'david30@hotmail.com',
#    'phone': '001-034-624-8811x93395'},
#   {'supplier_name': 'Turner-Davis',
#    'contact_name': 'Matthew Walker',
#    'email': 'wmurphy@mathis.org',
#    'phone': '579-218-9601x54220'},
#   {'supplier_name': 'Hall-Brown',
#    'contact_name': 'Richard Ballard',
#    'email': 'horneandrew@morgan.biz',
#    'phone': '+1-500-926-9681'},
#   {'supplier_name': 'Clark Group',
#    'contact_name': 'Stephen George DVM',
#    'email': 'royjessica@hotmail.com',
#    'phone': '(769)553-5373'},
#   {'supplier_name': 'Henderson LLC',
#    'contact_name': 'David Moore',
#    'email': 'benjamin57@yahoo.com',
#    'phone': '122.972.2988x83535'},
#   {'supplier_name': 'Rowe PLC',
#    'contact_name': 'Kevin Mcpherson',
#    'email': 'marco90@edwards-moran.com',
#    'phone': '496-064-5206x9241'},
#   {'supplier_name': 'Rogers-Greene',
#    'contact_name': 'Brady Brown',
#    'email': 'mcdowellkimberly@hotmail.com',
#    'phone': '883-297-7964x15108'},
#   {'supplier_name': 'Patrick, Walter and Harrison',
#    'contact_name': 'Mark Stevens',
#    'email': 'ymiller@hotmail.com',
#    'phone': '(561)464-9376x280'},
#   {'supplier_name': 'Williams Ltd',
#    'contact_name': 'Jeffery Allen',
#    'email': 'jcooper@kim-cook.org',
#    'phone': '316-798-3465x4653'},
#   {'supplier_name': 'Morgan-Andrews',
#    'contact_name': 'Cathy Marshall',
#    'email': 'fjohnson@gmail.com',
#    'phone': '088-233-7178x6223'},
#   {'supplier_name': 'Armstrong-Vance',
#    'contact_name': 'Regina Nicholson',
#    'email': 'jacobsonjohn@hotmail.com',
#    'phone': '+1-836-020-7265x14208'},
#   {'supplier_name': 'Morgan Inc',
#    'contact_name': 'Eric Farmer',
#    'email': 'pricejaclyn@jimenez.com',
#    'phone': '(672)354-2529x76848'},
#   {'supplier_name': 'Hensley-Branch',
#    'contact_name': 'Jordan Clark',
#    'email': 'alextucker@freeman.com',
#    'phone': '(120)216-0730x2946'}],
#  'Product with suppliers and stock': [{'product_name': 'Ability Snack',
#    'supplier_name': 'Morgan Inc',
#    'stock_quantity': 755,
#    'reorder_level': 113},
#   {'product_name': 'Account Toy',
#    'supplier_name': 'Anderson-Thompson',
#    'stock_quantity': 758,
#    'reorder_level': 190},
#   {'product_name': 'Actually Toy',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 300,
#    'reorder_level': 181},
#   {'product_name': 'After Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 590,
#    'reorder_level': 165},
#   {'product_name': 'Against Table',
#    'supplier_name': 'Franklin, Kane and Price',
#    'stock_quantity': 267,
#    'reorder_level': 161},
#   {'product_name': 'Alone Toy',
#    'supplier_name': 'Henderson LLC',
#    'stock_quantity': 691,
#    'reorder_level': 149},
#   {'product_name': 'Already Snack',
#    'supplier_name': 'Kaufman Ltd',
#    'stock_quantity': 692,
#    'reorder_level': 60},
#   {'product_name': 'Among Toy',
#    'supplier_name': 'Baxter-Meadows',
#    'stock_quantity': 708,
#    'reorder_level': 117},
#   {'product_name': 'Amount Snack',
#    'supplier_name': 'Freeman-Gordon',
#    'stock_quantity': 631,
#    'reorder_level': 98},
#   {'product_name': 'And Table',
#    'supplier_name': 'Henderson LLC',
#    'stock_quantity': 100,
#    'reorder_level': 99},
#   {'product_name': 'Another Device',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 357,
#    'reorder_level': 193},
#   {'product_name': 'Appear Toy',
#    'supplier_name': 'Rowe PLC',
#    'stock_quantity': 815,
#    'reorder_level': 138},
#   {'product_name': 'As Toy',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 865,
#    'reorder_level': 120},
#   {'product_name': 'Ask Table',
#    'supplier_name': 'Rowland Ltd',
#    'stock_quantity': 674,
#    'reorder_level': 97},
#   {'product_name': 'Audience Snack',
#    'supplier_name': 'Wilson, Graham and Williams',
#    'stock_quantity': 467,
#    'reorder_level': 148},
#   {'product_name': 'Bag Table',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 545,
#    'reorder_level': 189},
#   {'product_name': 'Base Device',
#    'supplier_name': 'Charles Inc',
#    'stock_quantity': 691,
#    'reorder_level': 178},
#   {'product_name': 'Base Toy',
#    'supplier_name': 'Elliott-Ayers',
#    'stock_quantity': 220,
#    'reorder_level': 61},
#   {'product_name': 'Become Device',
#    'supplier_name': 'Moss-Evans',
#    'stock_quantity': 633,
#    'reorder_level': 116},
#   {'product_name': 'Bed Toy',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 723,
#    'reorder_level': 140},
#   {'product_name': 'Between Shirt',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 107,
#    'reorder_level': 58},
#   {'product_name': 'Between Toy',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 625,
#    'reorder_level': 190},
#   {'product_name': 'Billion Device',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 818,
#    'reorder_level': 138},
#   {'product_name': 'Blue Device',
#    'supplier_name': 'Morgan-Andrews',
#    'stock_quantity': 525,
#    'reorder_level': 54},
#   {'product_name': 'Book Device',
#    'supplier_name': 'Morgan Inc',
#    'stock_quantity': 46,
#    'reorder_level': 66},
#   {'product_name': 'Building Snack',
#    'supplier_name': 'Kaufman Ltd',
#    'stock_quantity': 4,
#    'reorder_level': 92},
#   {'product_name': 'Certain Device',
#    'supplier_name': 'Gomez PLC',
#    'stock_quantity': 10,
#    'reorder_level': 112},
#   {'product_name': 'Character Snack',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 629,
#    'reorder_level': 198},
#   {'product_name': 'Character Table',
#    'supplier_name': 'Williams Ltd',
#    'stock_quantity': 612,
#    'reorder_level': 187},
#   {'product_name': 'Check Snack',
#    'supplier_name': 'Rogers-Greene',
#    'stock_quantity': 891,
#    'reorder_level': 93},
#   {'product_name': 'Choose Snack',
#    'supplier_name': 'Rowland Ltd',
#    'stock_quantity': 406,
#    'reorder_level': 118},
#   {'product_name': 'Close Toy',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 46,
#    'reorder_level': 161},
#   {'product_name': 'Coach Snack',
#    'supplier_name': 'Stewart, Williams and Cox',
#    'stock_quantity': 825,
#    'reorder_level': 124},
#   {'product_name': 'Conference Snack',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 417,
#    'reorder_level': 96},
#   {'product_name': 'Could Device',
#    'supplier_name': 'Kaufman Ltd',
#    'stock_quantity': 628,
#    'reorder_level': 83},
#   {'product_name': 'Couple Shirt',
#    'supplier_name': 'Hall-Brown',
#    'stock_quantity': 50,
#    'reorder_level': 138},
#   {'product_name': 'Decade Shirt',
#    'supplier_name': 'Kaufman Ltd',
#    'stock_quantity': 219,
#    'reorder_level': 56},
#   {'product_name': 'Describe Toy',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 770,
#    'reorder_level': 83},
#   {'product_name': 'Determine Table',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'stock_quantity': 278,
#    'reorder_level': 144},
#   {'product_name': 'Discuss Toy',
#    'supplier_name': 'Mann-Marshall',
#    'stock_quantity': 117,
#    'reorder_level': 188},
#   {'product_name': 'Door Toy',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 11,
#    'reorder_level': 178},
#   {'product_name': 'During Toy',
#    'supplier_name': 'Tucker-Arnold',
#    'stock_quantity': 967,
#    'reorder_level': 188},
#   {'product_name': 'Enter Table',
#    'supplier_name': 'Barker, White and Carson',
#    'stock_quantity': 512,
#    'reorder_level': 72},
#   {'product_name': 'Environment Table',
#    'supplier_name': 'Reynolds-Phillips',
#    'stock_quantity': 667,
#    'reorder_level': 106},
#   {'product_name': 'Environmental Device',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'stock_quantity': 881,
#    'reorder_level': 93},
#   {'product_name': 'Everyone Snack',
#    'supplier_name': 'Henderson LLC',
#    'stock_quantity': 332,
#    'reorder_level': 119},
#   {'product_name': 'Executive Table',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 38,
#    'reorder_level': 140},
#   {'product_name': 'Expert Snack',
#    'supplier_name': 'Morgan-Andrews',
#    'stock_quantity': 116,
#    'reorder_level': 98},
#   {'product_name': 'Fact Device',
#    'supplier_name': 'Vega, Cook and Miller',
#    'stock_quantity': 260,
#    'reorder_level': 174},
#   {'product_name': 'Fast Shirt',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 863,
#    'reorder_level': 105},
#   {'product_name': 'Feeling Toy',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 441,
#    'reorder_level': 71},
#   {'product_name': 'Final Toy',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 976,
#    'reorder_level': 98},
#   {'product_name': 'Floor Table',
#    'supplier_name': 'Reynolds-Phillips',
#    'stock_quantity': 460,
#    'reorder_level': 105},
#   {'product_name': 'Floor Toy',
#    'supplier_name': 'Young, Browning and Ware',
#    'stock_quantity': 67,
#    'reorder_level': 194},
#   {'product_name': 'Foreign Table',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'stock_quantity': 959,
#    'reorder_level': 86},
#   {'product_name': 'Former Device',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 778,
#    'reorder_level': 173},
#   {'product_name': 'Former Device',
#    'supplier_name': 'Lloyd and Sons',
#    'stock_quantity': 939,
#    'reorder_level': 102},
#   {'product_name': 'Four Shirt',
#    'supplier_name': 'Elliott-Ayers',
#    'stock_quantity': 63,
#    'reorder_level': 175},
#   {'product_name': 'From Table',
#    'supplier_name': 'Reynolds-Phillips',
#    'stock_quantity': 247,
#    'reorder_level': 149},
#   {'product_name': 'Full Table',
#    'supplier_name': 'Young, Browning and Ware',
#    'stock_quantity': 591,
#    'reorder_level': 122},
#   {'product_name': 'Fund Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 61,
#    'reorder_level': 112},
#   {'product_name': 'Gas Snack',
#    'supplier_name': 'Williams Ltd',
#    'stock_quantity': 337,
#    'reorder_level': 93},
#   {'product_name': 'Give Shirt',
#    'supplier_name': 'Lloyd and Sons',
#    'stock_quantity': 240,
#    'reorder_level': 61},
#   {'product_name': 'Give Snack',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 677,
#    'reorder_level': 143},
#   {'product_name': 'Ground Device',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 533,
#    'reorder_level': 116},
#   {'product_name': 'Growth Snack',
#    'supplier_name': 'Douglas Ltd',
#    'stock_quantity': 360,
#    'reorder_level': 67},
#   {'product_name': 'Growth Snack',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 257,
#    'reorder_level': 87},
#   {'product_name': 'Gun Device',
#    'supplier_name': 'Kaufman Ltd',
#    'stock_quantity': 556,
#    'reorder_level': 134},
#   {'product_name': 'Guy Device',
#    'supplier_name': 'Charles Inc',
#    'stock_quantity': 274,
#    'reorder_level': 93},
#   {'product_name': 'Hand Snack',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 233,
#    'reorder_level': 82},
#   {'product_name': 'Hard Snack',
#    'supplier_name': 'Evans Inc',
#    'stock_quantity': 79,
#    'reorder_level': 200},
#   {'product_name': 'Help Snack',
#    'supplier_name': 'Miller-Martinez',
#    'stock_quantity': 357,
#    'reorder_level': 142},
#   {'product_name': 'Himself Toy',
#    'supplier_name': 'Hall-Brown',
#    'stock_quantity': 347,
#    'reorder_level': 105},
#   {'product_name': 'Hold Toy',
#    'supplier_name': 'Mann-Marshall',
#    'stock_quantity': 695,
#    'reorder_level': 155},
#   {'product_name': 'Hospital Shirt',
#    'supplier_name': 'Hensley-Branch',
#    'stock_quantity': 444,
#    'reorder_level': 120},
#   {'product_name': 'However Snack',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 707,
#    'reorder_level': 95},
#   {'product_name': 'However Table',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 43,
#    'reorder_level': 52},
#   {'product_name': 'If Table',
#    'supplier_name': 'Mann-Marshall',
#    'stock_quantity': 393,
#    'reorder_level': 50},
#   {'product_name': 'Improve Snack',
#    'supplier_name': 'Lloyd and Sons',
#    'stock_quantity': 869,
#    'reorder_level': 181},
#   {'product_name': 'Include Device',
#    'supplier_name': 'Williams Ltd',
#    'stock_quantity': 856,
#    'reorder_level': 55},
#   {'product_name': 'Information Snack',
#    'supplier_name': 'Gallagher-Miller',
#    'stock_quantity': 708,
#    'reorder_level': 65},
#   {'product_name': 'Instead Snack',
#    'supplier_name': 'Freeman-Gordon',
#    'stock_quantity': 231,
#    'reorder_level': 51},
#   {'product_name': 'Instead Table',
#    'supplier_name': 'Elliott-Ayers',
#    'stock_quantity': 620,
#    'reorder_level': 99},
#   {'product_name': 'Investment Toy',
#    'supplier_name': 'Gallagher-Miller',
#    'stock_quantity': 834,
#    'reorder_level': 142},
#   {'product_name': 'Issue Device',
#    'supplier_name': 'Henderson LLC',
#    'stock_quantity': 412,
#    'reorder_level': 189},
#   {'product_name': 'Itself Shirt',
#    'supplier_name': 'Gallagher-Miller',
#    'stock_quantity': 133,
#    'reorder_level': 125},
#   {'product_name': 'Job Snack',
#    'supplier_name': 'Barrett Ltd',
#    'stock_quantity': 447,
#    'reorder_level': 120},
#   {'product_name': 'Just Device',
#    'supplier_name': 'Charles Inc',
#    'stock_quantity': 847,
#    'reorder_level': 114},
#   {'product_name': 'Later Toy',
#    'supplier_name': 'Tucker-Arnold',
#    'stock_quantity': 121,
#    'reorder_level': 61},
#   {'product_name': 'Law Device',
#    'supplier_name': 'Kaufman Ltd',
#    'stock_quantity': 485,
#    'reorder_level': 70},
#   {'product_name': 'Law Shirt',
#    'supplier_name': 'Ortega-Mahoney',
#    'stock_quantity': 675,
#    'reorder_level': 126},
#   {'product_name': 'Law Toy',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 931,
#    'reorder_level': 90},
#   {'product_name': 'Lead Toy',
#    'supplier_name': 'Gomez PLC',
#    'stock_quantity': 921,
#    'reorder_level': 156},
#   {'product_name': 'Least Table',
#    'supplier_name': 'Anderson-Thompson',
#    'stock_quantity': 58,
#    'reorder_level': 71},
#   {'product_name': 'Leave Device',
#    'supplier_name': 'Vega, Cook and Miller',
#    'stock_quantity': 521,
#    'reorder_level': 173},
#   {'product_name': 'Like Shirt',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'stock_quantity': 334,
#    'reorder_level': 131},
#   {'product_name': 'Local Shirt',
#    'supplier_name': 'Moss-Evans',
#    'stock_quantity': 749,
#    'reorder_level': 110},
#   {'product_name': 'Local Snack',
#    'supplier_name': 'Moss-Evans',
#    'stock_quantity': 861,
#    'reorder_level': 72},
#   {'product_name': 'Lose Toy',
#    'supplier_name': 'Mendoza-Jones',
#    'stock_quantity': 127,
#    'reorder_level': 92},
#   {'product_name': 'Manage Snack',
#    'supplier_name': 'Armstrong-Vance',
#    'stock_quantity': 63,
#    'reorder_level': 171},
#   {'product_name': 'Manage Table',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 328,
#    'reorder_level': 158},
#   {'product_name': 'Material Snack',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 451,
#    'reorder_level': 145},
#   {'product_name': 'Meet Shirt',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 892,
#    'reorder_level': 76},
#   {'product_name': 'Meeting Shirt',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 642,
#    'reorder_level': 143},
#   {'product_name': 'Member Toy',
#    'supplier_name': 'Hensley-Branch',
#    'stock_quantity': 516,
#    'reorder_level': 53},
#   {'product_name': 'Military Shirt',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'stock_quantity': 411,
#    'reorder_level': 110},
#   {'product_name': 'Mission Snack',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 893,
#    'reorder_level': 59},
#   {'product_name': 'Most Shirt',
#    'supplier_name': 'Freeman-Gordon',
#    'stock_quantity': 560,
#    'reorder_level': 93},
#   {'product_name': 'Mouth Shirt',
#    'supplier_name': 'Young, Browning and Ware',
#    'stock_quantity': 502,
#    'reorder_level': 99},
#   {'product_name': 'Movie Snack',
#    'supplier_name': 'Ortega-Mahoney',
#    'stock_quantity': 979,
#    'reorder_level': 131},
#   {'product_name': 'Mr Snack',
#    'supplier_name': 'Henderson LLC',
#    'stock_quantity': 944,
#    'reorder_level': 179},
#   {'product_name': 'National Shirt',
#    'supplier_name': 'Barrett Ltd',
#    'stock_quantity': 394,
#    'reorder_level': 198},
#   {'product_name': 'Necessary Device',
#    'supplier_name': 'Baxter-Meadows',
#    'stock_quantity': 298,
#    'reorder_level': 193},
#   {'product_name': 'Next Device',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 26,
#    'reorder_level': 200},
#   {'product_name': 'Nor Snack',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 122,
#    'reorder_level': 194},
#   {'product_name': 'North Shirt',
#    'supplier_name': 'Rowe PLC',
#    'stock_quantity': 644,
#    'reorder_level': 152},
#   {'product_name': 'Nothing Snack',
#    'supplier_name': 'Turner-Davis',
#    'stock_quantity': 375,
#    'reorder_level': 81},
#   {'product_name': 'Notice Toy',
#    'supplier_name': 'Evans Inc',
#    'stock_quantity': 640,
#    'reorder_level': 113},
#   {'product_name': 'Notice Toy',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 866,
#    'reorder_level': 60},
#   {'product_name': 'Old Shirt',
#    'supplier_name': 'Elliott-Ayers',
#    'stock_quantity': 996,
#    'reorder_level': 130},
#   {'product_name': 'Onto Shirt',
#    'supplier_name': 'Mann-Marshall',
#    'stock_quantity': 98,
#    'reorder_level': 62},
#   {'product_name': 'Paper Toy',
#    'supplier_name': 'Miller-Martinez',
#    'stock_quantity': 212,
#    'reorder_level': 101},
#   {'product_name': 'Part Device',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 652,
#    'reorder_level': 88},
#   {'product_name': 'Personal Table',
#    'supplier_name': 'Turner-Davis',
#    'stock_quantity': 962,
#    'reorder_level': 59},
#   {'product_name': 'Phone Shirt',
#    'supplier_name': 'Armstrong-Vance',
#    'stock_quantity': 97,
#    'reorder_level': 91},
#   {'product_name': 'Piece Device',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'stock_quantity': 536,
#    'reorder_level': 191},
#   {'product_name': 'Player Device',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'stock_quantity': 530,
#    'reorder_level': 132},
#   {'product_name': 'Poor Snack',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 677,
#    'reorder_level': 143},
#   {'product_name': 'Race Device',
#    'supplier_name': 'Baxter-Meadows',
#    'stock_quantity': 108,
#    'reorder_level': 183},
#   {'product_name': 'Reach Device',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 623,
#    'reorder_level': 179},
#   {'product_name': 'Real Snack',
#    'supplier_name': 'Wong Group',
#    'stock_quantity': 4,
#    'reorder_level': 182},
#   {'product_name': 'Reality Table',
#    'supplier_name': 'Rowe PLC',
#    'stock_quantity': 804,
#    'reorder_level': 54},
#   {'product_name': 'Really Snack',
#    'supplier_name': 'Stewart, Williams and Cox',
#    'stock_quantity': 424,
#    'reorder_level': 160},
#   {'product_name': 'Region Toy',
#    'supplier_name': 'Wong Group',
#    'stock_quantity': 488,
#    'reorder_level': 68},
#   {'product_name': 'Report Toy',
#    'supplier_name': 'Hall-Brown',
#    'stock_quantity': 575,
#    'reorder_level': 166},
#   {'product_name': 'Require Toy',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 987,
#    'reorder_level': 102},
#   {'product_name': 'Return Table',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'stock_quantity': 39,
#    'reorder_level': 182},
#   {'product_name': 'Return Table',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 177,
#    'reorder_level': 75},
#   {'product_name': 'Run Device',
#    'supplier_name': 'Ortega-Mahoney',
#    'stock_quantity': 341,
#    'reorder_level': 111},
#   {'product_name': 'Scene Table',
#    'supplier_name': 'Freeman-Gordon',
#    'stock_quantity': 645,
#    'reorder_level': 74},
#   {'product_name': 'School Table',
#    'supplier_name': 'Douglas Ltd',
#    'stock_quantity': 687,
#    'reorder_level': 100},
#   {'product_name': 'Scientist Table',
#    'supplier_name': 'Franklin, Kane and Price',
#    'stock_quantity': 902,
#    'reorder_level': 114},
#   {'product_name': 'Security Shirt',
#    'supplier_name': 'Wilson, Graham and Williams',
#    'stock_quantity': 25,
#    'reorder_level': 70},
#   {'product_name': 'Sense Snack',
#    'supplier_name': 'Turner-Davis',
#    'stock_quantity': 675,
#    'reorder_level': 161},
#   {'product_name': 'Seven Table',
#    'supplier_name': 'Clark Group',
#    'stock_quantity': 649,
#    'reorder_level': 114},
#   {'product_name': 'Seven Table',
#    'supplier_name': 'Lawrence, Garcia and Hernandez',
#    'stock_quantity': 856,
#    'reorder_level': 120},
#   {'product_name': 'Several Snack',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 652,
#    'reorder_level': 199},
#   {'product_name': 'Sign Toy',
#    'supplier_name': 'Charles Inc',
#    'stock_quantity': 768,
#    'reorder_level': 169},
#   {'product_name': 'Simple Device',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 888,
#    'reorder_level': 77},
#   {'product_name': 'Since Shirt',
#    'supplier_name': 'Turner-Davis',
#    'stock_quantity': 304,
#    'reorder_level': 155},
#   {'product_name': 'Sit Toy',
#    'supplier_name': 'Williams Ltd',
#    'stock_quantity': 474,
#    'reorder_level': 121},
#   {'product_name': 'Six Device',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 493,
#    'reorder_level': 100},
#   {'product_name': 'Six Table',
#    'supplier_name': 'Douglas Ltd',
#    'stock_quantity': 442,
#    'reorder_level': 76},
#   {'product_name': 'SmartWatch',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'stock_quantity': 100,
#    'reorder_level': 25},
#   {'product_name': 'So Table',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 723,
#    'reorder_level': 60},
#   {'product_name': 'Someone Shirt',
#    'supplier_name': 'Hensley-Branch',
#    'stock_quantity': 801,
#    'reorder_level': 105},
#   {'product_name': 'Sound Snack',
#    'supplier_name': 'Hall-Brown',
#    'stock_quantity': 89,
#    'reorder_level': 59},
#   {'product_name': 'Sound Table',
#    'supplier_name': 'Morgan Inc',
#    'stock_quantity': 256,
#    'reorder_level': 84},
#   {'product_name': 'South Device',
#    'supplier_name': 'Hensley-Branch',
#    'stock_quantity': 742,
#    'reorder_level': 196},
#   {'product_name': 'Space Toy',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 693,
#    'reorder_level': 126},
#   {'product_name': 'Speak Shirt',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 540,
#    'reorder_level': 80},
#   {'product_name': 'Spring Toy',
#    'supplier_name': 'Vega, Cook and Miller',
#    'stock_quantity': 336,
#    'reorder_level': 199},
#   {'product_name': 'Staff Shirt',
#    'supplier_name': 'Rowland Ltd',
#    'stock_quantity': 191,
#    'reorder_level': 200},
#   {'product_name': 'Start Table',
#    'supplier_name': 'Barker, White and Carson',
#    'stock_quantity': 865,
#    'reorder_level': 147},
#   {'product_name': 'Still Snack',
#    'supplier_name': 'Rowland Ltd',
#    'stock_quantity': 433,
#    'reorder_level': 178},
#   {'product_name': 'Store Toy',
#    'supplier_name': 'Miller-Martinez',
#    'stock_quantity': 874,
#    'reorder_level': 50},
#   {'product_name': 'Story Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 510,
#    'reorder_level': 116},
#   {'product_name': 'Suddenly Device',
#    'supplier_name': 'Rogers-Greene',
#    'stock_quantity': 372,
#    'reorder_level': 183},
#   {'product_name': 'Suddenly Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 53,
#    'reorder_level': 166},
#   {'product_name': 'Summer Device',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 320,
#    'reorder_level': 96},
#   {'product_name': 'Sure Toy',
#    'supplier_name': 'Mann-Marshall',
#    'stock_quantity': 309,
#    'reorder_level': 125},
#   {'product_name': 'Surface Shirt',
#    'supplier_name': 'Vega, Cook and Miller',
#    'stock_quantity': 530,
#    'reorder_level': 137},
#   {'product_name': 'System Snack',
#    'supplier_name': 'Barker, White and Carson',
#    'stock_quantity': 503,
#    'reorder_level': 138},
#   {'product_name': 'Tax Device',
#    'supplier_name': 'Morgan Inc',
#    'stock_quantity': 644,
#    'reorder_level': 84},
#   {'product_name': 'Teacher Toy',
#    'supplier_name': 'Barrett Ltd',
#    'stock_quantity': 436,
#    'reorder_level': 189},
#   {'product_name': 'Thank Shirt',
#    'supplier_name': 'Barker, White and Carson',
#    'stock_quantity': 902,
#    'reorder_level': 83},
#   {'product_name': 'These Snack',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 998,
#    'reorder_level': 163},
#   {'product_name': 'This Snack',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 20,
#    'reorder_level': 66},
#   {'product_name': 'Thought Toy',
#    'supplier_name': 'Stewart, Williams and Cox',
#    'stock_quantity': 147,
#    'reorder_level': 157},
#   {'product_name': 'Thought Toy',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 936,
#    'reorder_level': 133},
#   {'product_name': 'Throughout Snack',
#    'supplier_name': 'Williams Ltd',
#    'stock_quantity': 451,
#    'reorder_level': 57},
#   {'product_name': 'Throughout Snack',
#    'supplier_name': 'Henderson LLC',
#    'stock_quantity': 248,
#    'reorder_level': 118},
#   {'product_name': 'Throughout Toy',
#    'supplier_name': 'Wong Group',
#    'stock_quantity': 192,
#    'reorder_level': 118},
#   {'product_name': 'Throw Device',
#    'supplier_name': 'Young, Browning and Ware',
#    'stock_quantity': 862,
#    'reorder_level': 191},
#   {'product_name': 'Throw Toy',
#    'supplier_name': 'Morgan-Andrews',
#    'stock_quantity': 93,
#    'reorder_level': 155},
#   {'product_name': 'Tough Shirt',
#    'supplier_name': 'Gallagher-Miller',
#    'stock_quantity': 660,
#    'reorder_level': 154},
#   {'product_name': 'Town Toy',
#    'supplier_name': 'Morgan Inc',
#    'stock_quantity': 376,
#    'reorder_level': 182},
#   {'product_name': 'Treat Device',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'stock_quantity': 122,
#    'reorder_level': 89},
#   {'product_name': 'Trouble Table',
#    'supplier_name': 'Moss-Evans',
#    'stock_quantity': 826,
#    'reorder_level': 166},
#   {'product_name': 'True Snack',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 741,
#    'reorder_level': 200},
#   {'product_name': 'Truth Device',
#    'supplier_name': 'Lloyd and Sons',
#    'stock_quantity': 570,
#    'reorder_level': 78},
#   {'product_name': 'Value Table',
#    'supplier_name': 'Douglas Ltd',
#    'stock_quantity': 480,
#    'reorder_level': 199},
#   {'product_name': 'Wait Toy',
#    'supplier_name': 'Mann-Marshall',
#    'stock_quantity': 164,
#    'reorder_level': 164},
#   {'product_name': 'Way Snack',
#    'supplier_name': 'Hall-Brown',
#    'stock_quantity': 725,
#    'reorder_level': 77},
#   {'product_name': 'Where Toy',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 848,
#    'reorder_level': 80},
#   {'product_name': 'White Table',
#    'supplier_name': 'Morgan-Andrews',
#    'stock_quantity': 702,
#    'reorder_level': 143},
#   {'product_name': 'Whom Table',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 727,
#    'reorder_level': 186},
#   {'product_name': 'Whose Snack',
#    'supplier_name': 'Wong Group',
#    'stock_quantity': 182,
#    'reorder_level': 177},
#   {'product_name': 'Within Toy',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 839,
#    'reorder_level': 193},
#   {'product_name': 'Within Toy',
#    'supplier_name': 'Rogers-Greene',
#    'stock_quantity': 26,
#    'reorder_level': 189},
#   {'product_name': 'Writer Table',
#    'supplier_name': 'Anderson-Thompson',
#    'stock_quantity': 700,
#    'reorder_level': 198}],
#  'Product needing reorder': [{'product_id': 19,
#    'product_name': 'Next Device',
#    'stock_quantity': 26,
#    'reorder_level': 200},
#   {'product_id': 36,
#    'product_name': 'Race Device',
#    'stock_quantity': 108,
#    'reorder_level': 183},
#   {'product_id': 46,
#    'product_name': 'Close Toy',
#    'stock_quantity': 46,
#    'reorder_level': 161},
#   {'product_id': 50,
#    'product_name': 'Hard Snack',
#    'stock_quantity': 79,
#    'reorder_level': 200},
#   {'product_id': 51,
#    'product_name': 'Staff Shirt',
#    'stock_quantity': 191,
#    'reorder_level': 200},
#   {'product_id': 58,
#    'product_name': 'Floor Toy',
#    'stock_quantity': 67,
#    'reorder_level': 194},
#   {'product_id': 62,
#    'product_name': 'Throw Toy',
#    'stock_quantity': 93,
#    'reorder_level': 155},
#   {'product_id': 100,
#    'product_name': 'Fund Table',
#    'stock_quantity': 61,
#    'reorder_level': 112},
#   {'product_id': 108,
#    'product_name': 'Executive Table',
#    'stock_quantity': 38,
#    'reorder_level': 140},
#   {'product_id': 110,
#    'product_name': 'However Table',
#    'stock_quantity': 43,
#    'reorder_level': 52},
#   {'product_id': 113,
#    'product_name': 'Certain Device',
#    'stock_quantity': 10,
#    'reorder_level': 112},
#   {'product_id': 132,
#    'product_name': 'This Snack',
#    'stock_quantity': 20,
#    'reorder_level': 66},
#   {'product_id': 136,
#    'product_name': 'Within Toy',
#    'stock_quantity': 26,
#    'reorder_level': 189},
#   {'product_id': 137,
#    'product_name': 'Least Table',
#    'stock_quantity': 58,
#    'reorder_level': 71},
#   {'product_id': 144,
#    'product_name': 'Building Snack',
#    'stock_quantity': 4,
#    'reorder_level': 92},
#   {'product_id': 150,
#    'product_name': 'Return Table',
#    'stock_quantity': 39,
#    'reorder_level': 182},
#   {'product_id': 153,
#    'product_name': 'Security Shirt',
#    'stock_quantity': 25,
#    'reorder_level': 70},
#   {'product_id': 154,
#    'product_name': 'Manage Snack',
#    'stock_quantity': 63,
#    'reorder_level': 171},
#   {'product_id': 160,
#    'product_name': 'Suddenly Table',
#    'stock_quantity': 53,
#    'reorder_level': 166},
#   {'product_id': 165,
#    'product_name': 'Nor Snack',
#    'stock_quantity': 122,
#    'reorder_level': 194},
#   {'product_id': 167,
#    'product_name': 'Discuss Toy',
#    'stock_quantity': 117,
#    'reorder_level': 188},
#   {'product_id': 169,
#    'product_name': 'Four Shirt',
#    'stock_quantity': 63,
#    'reorder_level': 175},
#   {'product_id': 173,
#    'product_name': 'Real Snack',
#    'stock_quantity': 4,
#    'reorder_level': 182},
#   {'product_id': 180,
#    'product_name': 'Door Toy',
#    'stock_quantity': 11,
#    'reorder_level': 178},
#   {'product_id': 185,
#    'product_name': 'Couple Shirt',
#    'stock_quantity': 50,
#    'reorder_level': 138},
#   {'product_id': 192,
#    'product_name': 'Thought Toy',
#    'stock_quantity': 147,
#    'reorder_level': 157},
#   {'product_id': 199,
#    'product_name': 'Book Device',
#    'stock_quantity': 46,
#    'reorder_level': 66}]}

# %%
def get_additional_tables(cursor):
    queries = {
    "Suppliers contact details": "select supplier_name, contact_name, email, phone from suppliers;",

    "Product with suppliers and stock": """
    select p.product_name, s.supplier_name, p.stock_quantity, p.reorder_level
    from products as p
    join suppliers as s
    on p.supplier_id = s.supplier_id
    order by p.product_name;
    """,

    "Product needing reorder":""" 
    select product_id, product_name, stock_quantity, reorder_level
    from products 
    where stock_quantity < reorder_level
    """
    }
    
    tables={}

    for label, query in queries.items():
        cursor.execute(query)
        tables[label] = cursor.fetchall()

    return tables

# %%
get_additional_tables(cursor)
# Out:
# {'Suppliers contact details': [{'supplier_name': 'Anderson-Thompson',
#    'contact_name': 'Bonnie Davis',
#    'email': 'zacharysanchez@hotmail.com',
#    'phone': '829.485.9853x0522'},
#   {'supplier_name': 'Rowland Ltd',
#    'contact_name': 'Beth Stevens',
#    'email': 'joshua60@yahoo.com',
#    'phone': '(779)942-0726'},
#   {'supplier_name': 'Baxter-Meadows',
#    'contact_name': 'Lisa Lewis',
#    'email': 'andersonchristina@yahoo.com',
#    'phone': '449-766-7325'},
#   {'supplier_name': 'Wilson, Graham and Williams',
#    'contact_name': 'David Martinez',
#    'email': 'abrown@hotmail.com',
#    'phone': '+1-653-827-5215x266'},
#   {'supplier_name': 'Smith, Kennedy and Moreno',
#    'contact_name': 'Victoria Gonzalez',
#    'email': 'mary30@williams-moore.com',
#    'phone': '891-859-2775x35297'},
#   {'supplier_name': 'Middleton LLC',
#    'contact_name': 'Megan Miller',
#    'email': 'kelseywilliams@gmail.com',
#    'phone': '001-724-731-6199x4596'},
#   {'supplier_name': 'Evans Inc',
#    'contact_name': 'Danielle Moore',
#    'email': 'ihoffman@warren.com',
#    'phone': '+1-951-447-1975x770'},
#   {'supplier_name': 'Lawrence, Garcia and Hernandez',
#    'contact_name': 'Tamara Johnson',
#    'email': 'georgeherrera@hotmail.com',
#    'phone': '+1-635-460-8476x270'},
#   {'supplier_name': 'Young, Browning and Ware',
#    'contact_name': 'Heather Hill',
#    'email': 'stephensjason@yahoo.com',
#    'phone': '(514)361-6411x489'},
#   {'supplier_name': 'Newton, Valencia and Carr',
#    'contact_name': 'Kimberly Collins',
#    'email': 'jonathanjohnston@ashley-williams.com',
#    'phone': '762-368-3504x8972'},
#   {'supplier_name': 'Vega, Cook and Miller',
#    'contact_name': 'Stephen Rogers',
#    'email': 'ianderson@thompson.com',
#    'phone': '(545)747-7182x90685'},
#   {'supplier_name': 'Mendoza-Jones',
#    'contact_name': 'Daniel Archer',
#    'email': 'clarketodd@bush-parker.com',
#    'phone': '077.020.6783x0807'},
#   {'supplier_name': 'Gallagher-Miller',
#    'contact_name': 'Michael Moore',
#    'email': 'jesse95@gmail.com',
#    'phone': '+1-462-260-2525x67365'},
#   {'supplier_name': 'Miller-Martinez',
#    'contact_name': 'Paula Morales',
#    'email': 'floresderek@yahoo.com',
#    'phone': '+1-700-794-1809x5862'},
#   {'supplier_name': 'Freeman-Gordon',
#    'contact_name': 'Zachary Garcia',
#    'email': 'angela33@humphrey.org',
#    'phone': '172-492-5671'},
#   {'supplier_name': 'Tucker-Arnold',
#    'contact_name': 'Katherine Lopez DVM',
#    'email': 'michelle03@hotmail.com',
#    'phone': '001-661-335-2179x4217'},
#   {'supplier_name': 'Gomez PLC',
#    'contact_name': 'James Fernandez',
#    'email': 'lovewarren@harris.info',
#    'phone': '661-353-3289'},
#   {'supplier_name': 'Moss-Evans',
#    'contact_name': 'Jennifer Green',
#    'email': 'crystalroth@yahoo.com',
#    'phone': '+1-877-605-7924x7393'},
#   {'supplier_name': 'Charles Inc',
#    'contact_name': 'Lori Liu',
#    'email': 'suzanne20@donaldson.net',
#    'phone': '+1-059-663-9297x67941'},
#   {'supplier_name': 'Ortega-Mahoney',
#    'contact_name': 'Teresa Miller',
#    'email': 'ile@hotmail.com',
#    'phone': '001-415-849-5736x81908'},
#   {'supplier_name': 'Mann-Marshall',
#    'contact_name': 'Scott Watts',
#    'email': 'colejoseph@hotmail.com',
#    'phone': '7317296630'},
#   {'supplier_name': 'Hudson Inc',
#    'contact_name': 'Michael Nguyen',
#    'email': 'ucochran@osborn.com',
#    'phone': '+1-563-056-3764x85079'},
#   {'supplier_name': 'Douglas Ltd',
#    'contact_name': 'Jonathan White',
#    'email': 'michael15@hotmail.com',
#    'phone': '001-734-858-5527x84897'},
#   {'supplier_name': 'Barker, White and Carson',
#    'contact_name': 'Cesar Moore',
#    'email': 'qhogan@yahoo.com',
#    'phone': '(521)673-3153x7796'},
#   {'supplier_name': 'Barrett Ltd',
#    'contact_name': 'Kim Wheeler',
#    'email': 'william52@hotmail.com',
#    'phone': '+1-887-075-4700'},
#   {'supplier_name': 'Tran LLC',
#    'contact_name': 'Anthony Jacobs',
#    'email': 'bdavis@fuller.com',
#    'phone': '(460)711-5746'},
#   {'supplier_name': 'Franklin, Kane and Price',
#    'contact_name': 'John Mueller',
#    'email': 'mitchellpierce@gmail.com',
#    'phone': '230.183.6177x07682'},
#   {'supplier_name': 'Stewart, Williams and Cox',
#    'contact_name': 'Nichole Fuller',
#    'email': 'mitchelllauren@hotmail.com',
#    'phone': '001-632-585-1111x529'},
#   {'supplier_name': 'Johnson-Bass',
#    'contact_name': 'Megan Carroll',
#    'email': 'fernandeztiffany@page.net',
#    'phone': '3531846182'},
#   {'supplier_name': 'Lloyd and Sons',
#    'contact_name': 'Sarah Ross',
#    'email': 'heathkaren@gmail.com',
#    'phone': '064-804-0646x199'},
#   {'supplier_name': 'Taylor-Love',
#    'contact_name': 'Daniel Mcgrath',
#    'email': 'perrykeith@kennedy.com',
#    'phone': '841-905-8982x711'},
#   {'supplier_name': 'Elliott-Ayers',
#    'contact_name': 'Kelly Avery',
#    'email': 'joseph44@moore-soto.biz',
#    'phone': '768-127-8200x348'},
#   {'supplier_name': 'Reynolds-Phillips',
#    'contact_name': 'Ashlee Montoya',
#    'email': 'stonewesley@bowen-salinas.biz',
#    'phone': '+1-869-461-6007x4674'},
#   {'supplier_name': 'Moody-Vang',
#    'contact_name': 'Joseph Peterson',
#    'email': 'hward@hotmail.com',
#    'phone': '001-530-230-6560x82908'},
#   {'supplier_name': 'Perez, Price and Wallace',
#    'contact_name': 'James Rich',
#    'email': 'natashapierce@knox.com',
#    'phone': '409.569.6703'},
#   {'supplier_name': 'Wong Group',
#    'contact_name': 'Lauren Humphrey',
#    'email': 'hayeseric@george.com',
#    'phone': '546-100-3064x5276'},
#   {'supplier_name': 'Kaufman Ltd',
#    'contact_name': 'Chelsea Young',
#    'email': 'wendy80@smith.net',
#    'phone': '(434)045-1867x11846'},
#   {'supplier_name': 'Harris-Cummings',
#    'contact_name': 'Jonathan Foley',
#    'email': 'david30@hotmail.com',
#    'phone': '001-034-624-8811x93395'},
#   {'supplier_name': 'Turner-Davis',
#    'contact_name': 'Matthew Walker',
#    'email': 'wmurphy@mathis.org',
#    'phone': '579-218-9601x54220'},
#   {'supplier_name': 'Hall-Brown',
#    'contact_name': 'Richard Ballard',
#    'email': 'horneandrew@morgan.biz',
#    'phone': '+1-500-926-9681'},
#   {'supplier_name': 'Clark Group',
#    'contact_name': 'Stephen George DVM',
#    'email': 'royjessica@hotmail.com',
#    'phone': '(769)553-5373'},
#   {'supplier_name': 'Henderson LLC',
#    'contact_name': 'David Moore',
#    'email': 'benjamin57@yahoo.com',
#    'phone': '122.972.2988x83535'},
#   {'supplier_name': 'Rowe PLC',
#    'contact_name': 'Kevin Mcpherson',
#    'email': 'marco90@edwards-moran.com',
#    'phone': '496-064-5206x9241'},
#   {'supplier_name': 'Rogers-Greene',
#    'contact_name': 'Brady Brown',
#    'email': 'mcdowellkimberly@hotmail.com',
#    'phone': '883-297-7964x15108'},
#   {'supplier_name': 'Patrick, Walter and Harrison',
#    'contact_name': 'Mark Stevens',
#    'email': 'ymiller@hotmail.com',
#    'phone': '(561)464-9376x280'},
#   {'supplier_name': 'Williams Ltd',
#    'contact_name': 'Jeffery Allen',
#    'email': 'jcooper@kim-cook.org',
#    'phone': '316-798-3465x4653'},
#   {'supplier_name': 'Morgan-Andrews',
#    'contact_name': 'Cathy Marshall',
#    'email': 'fjohnson@gmail.com',
#    'phone': '088-233-7178x6223'},
#   {'supplier_name': 'Armstrong-Vance',
#    'contact_name': 'Regina Nicholson',
#    'email': 'jacobsonjohn@hotmail.com',
#    'phone': '+1-836-020-7265x14208'},
#   {'supplier_name': 'Morgan Inc',
#    'contact_name': 'Eric Farmer',
#    'email': 'pricejaclyn@jimenez.com',
#    'phone': '(672)354-2529x76848'},
#   {'supplier_name': 'Hensley-Branch',
#    'contact_name': 'Jordan Clark',
#    'email': 'alextucker@freeman.com',
#    'phone': '(120)216-0730x2946'}],
#  'Product with suppliers and stock': [{'product_name': 'Ability Snack',
#    'supplier_name': 'Morgan Inc',
#    'stock_quantity': 755,
#    'reorder_level': 113},
#   {'product_name': 'Account Toy',
#    'supplier_name': 'Anderson-Thompson',
#    'stock_quantity': 758,
#    'reorder_level': 190},
#   {'product_name': 'Actually Toy',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 300,
#    'reorder_level': 181},
#   {'product_name': 'After Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 590,
#    'reorder_level': 165},
#   {'product_name': 'Against Table',
#    'supplier_name': 'Franklin, Kane and Price',
#    'stock_quantity': 267,
#    'reorder_level': 161},
#   {'product_name': 'Alone Toy',
#    'supplier_name': 'Henderson LLC',
#    'stock_quantity': 691,
#    'reorder_level': 149},
#   {'product_name': 'Already Snack',
#    'supplier_name': 'Kaufman Ltd',
#    'stock_quantity': 692,
#    'reorder_level': 60},
#   {'product_name': 'Among Toy',
#    'supplier_name': 'Baxter-Meadows',
#    'stock_quantity': 708,
#    'reorder_level': 117},
#   {'product_name': 'Amount Snack',
#    'supplier_name': 'Freeman-Gordon',
#    'stock_quantity': 631,
#    'reorder_level': 98},
#   {'product_name': 'And Table',
#    'supplier_name': 'Henderson LLC',
#    'stock_quantity': 100,
#    'reorder_level': 99},
#   {'product_name': 'Another Device',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 357,
#    'reorder_level': 193},
#   {'product_name': 'Appear Toy',
#    'supplier_name': 'Rowe PLC',
#    'stock_quantity': 815,
#    'reorder_level': 138},
#   {'product_name': 'As Toy',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 865,
#    'reorder_level': 120},
#   {'product_name': 'Ask Table',
#    'supplier_name': 'Rowland Ltd',
#    'stock_quantity': 674,
#    'reorder_level': 97},
#   {'product_name': 'Audience Snack',
#    'supplier_name': 'Wilson, Graham and Williams',
#    'stock_quantity': 467,
#    'reorder_level': 148},
#   {'product_name': 'Bag Table',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 545,
#    'reorder_level': 189},
#   {'product_name': 'Base Device',
#    'supplier_name': 'Charles Inc',
#    'stock_quantity': 691,
#    'reorder_level': 178},
#   {'product_name': 'Base Toy',
#    'supplier_name': 'Elliott-Ayers',
#    'stock_quantity': 220,
#    'reorder_level': 61},
#   {'product_name': 'Become Device',
#    'supplier_name': 'Moss-Evans',
#    'stock_quantity': 633,
#    'reorder_level': 116},
#   {'product_name': 'Bed Toy',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 723,
#    'reorder_level': 140},
#   {'product_name': 'Between Shirt',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 107,
#    'reorder_level': 58},
#   {'product_name': 'Between Toy',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 625,
#    'reorder_level': 190},
#   {'product_name': 'Billion Device',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 818,
#    'reorder_level': 138},
#   {'product_name': 'Blue Device',
#    'supplier_name': 'Morgan-Andrews',
#    'stock_quantity': 525,
#    'reorder_level': 54},
#   {'product_name': 'Book Device',
#    'supplier_name': 'Morgan Inc',
#    'stock_quantity': 46,
#    'reorder_level': 66},
#   {'product_name': 'Building Snack',
#    'supplier_name': 'Kaufman Ltd',
#    'stock_quantity': 4,
#    'reorder_level': 92},
#   {'product_name': 'Certain Device',
#    'supplier_name': 'Gomez PLC',
#    'stock_quantity': 10,
#    'reorder_level': 112},
#   {'product_name': 'Character Snack',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 629,
#    'reorder_level': 198},
#   {'product_name': 'Character Table',
#    'supplier_name': 'Williams Ltd',
#    'stock_quantity': 612,
#    'reorder_level': 187},
#   {'product_name': 'Check Snack',
#    'supplier_name': 'Rogers-Greene',
#    'stock_quantity': 891,
#    'reorder_level': 93},
#   {'product_name': 'Choose Snack',
#    'supplier_name': 'Rowland Ltd',
#    'stock_quantity': 406,
#    'reorder_level': 118},
#   {'product_name': 'Close Toy',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 46,
#    'reorder_level': 161},
#   {'product_name': 'Coach Snack',
#    'supplier_name': 'Stewart, Williams and Cox',
#    'stock_quantity': 825,
#    'reorder_level': 124},
#   {'product_name': 'Conference Snack',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 417,
#    'reorder_level': 96},
#   {'product_name': 'Could Device',
#    'supplier_name': 'Kaufman Ltd',
#    'stock_quantity': 628,
#    'reorder_level': 83},
#   {'product_name': 'Couple Shirt',
#    'supplier_name': 'Hall-Brown',
#    'stock_quantity': 50,
#    'reorder_level': 138},
#   {'product_name': 'Decade Shirt',
#    'supplier_name': 'Kaufman Ltd',
#    'stock_quantity': 219,
#    'reorder_level': 56},
#   {'product_name': 'Describe Toy',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 770,
#    'reorder_level': 83},
#   {'product_name': 'Determine Table',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'stock_quantity': 278,
#    'reorder_level': 144},
#   {'product_name': 'Discuss Toy',
#    'supplier_name': 'Mann-Marshall',
#    'stock_quantity': 117,
#    'reorder_level': 188},
#   {'product_name': 'Door Toy',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 11,
#    'reorder_level': 178},
#   {'product_name': 'During Toy',
#    'supplier_name': 'Tucker-Arnold',
#    'stock_quantity': 967,
#    'reorder_level': 188},
#   {'product_name': 'Enter Table',
#    'supplier_name': 'Barker, White and Carson',
#    'stock_quantity': 512,
#    'reorder_level': 72},
#   {'product_name': 'Environment Table',
#    'supplier_name': 'Reynolds-Phillips',
#    'stock_quantity': 667,
#    'reorder_level': 106},
#   {'product_name': 'Environmental Device',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'stock_quantity': 881,
#    'reorder_level': 93},
#   {'product_name': 'Everyone Snack',
#    'supplier_name': 'Henderson LLC',
#    'stock_quantity': 332,
#    'reorder_level': 119},
#   {'product_name': 'Executive Table',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 38,
#    'reorder_level': 140},
#   {'product_name': 'Expert Snack',
#    'supplier_name': 'Morgan-Andrews',
#    'stock_quantity': 116,
#    'reorder_level': 98},
#   {'product_name': 'Fact Device',
#    'supplier_name': 'Vega, Cook and Miller',
#    'stock_quantity': 260,
#    'reorder_level': 174},
#   {'product_name': 'Fast Shirt',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 863,
#    'reorder_level': 105},
#   {'product_name': 'Feeling Toy',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 441,
#    'reorder_level': 71},
#   {'product_name': 'Final Toy',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 976,
#    'reorder_level': 98},
#   {'product_name': 'Floor Table',
#    'supplier_name': 'Reynolds-Phillips',
#    'stock_quantity': 460,
#    'reorder_level': 105},
#   {'product_name': 'Floor Toy',
#    'supplier_name': 'Young, Browning and Ware',
#    'stock_quantity': 67,
#    'reorder_level': 194},
#   {'product_name': 'Foreign Table',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'stock_quantity': 959,
#    'reorder_level': 86},
#   {'product_name': 'Former Device',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 778,
#    'reorder_level': 173},
#   {'product_name': 'Former Device',
#    'supplier_name': 'Lloyd and Sons',
#    'stock_quantity': 939,
#    'reorder_level': 102},
#   {'product_name': 'Four Shirt',
#    'supplier_name': 'Elliott-Ayers',
#    'stock_quantity': 63,
#    'reorder_level': 175},
#   {'product_name': 'From Table',
#    'supplier_name': 'Reynolds-Phillips',
#    'stock_quantity': 247,
#    'reorder_level': 149},
#   {'product_name': 'Full Table',
#    'supplier_name': 'Young, Browning and Ware',
#    'stock_quantity': 591,
#    'reorder_level': 122},
#   {'product_name': 'Fund Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 61,
#    'reorder_level': 112},
#   {'product_name': 'Gas Snack',
#    'supplier_name': 'Williams Ltd',
#    'stock_quantity': 337,
#    'reorder_level': 93},
#   {'product_name': 'Give Shirt',
#    'supplier_name': 'Lloyd and Sons',
#    'stock_quantity': 240,
#    'reorder_level': 61},
#   {'product_name': 'Give Snack',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 677,
#    'reorder_level': 143},
#   {'product_name': 'Ground Device',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 533,
#    'reorder_level': 116},
#   {'product_name': 'Growth Snack',
#    'supplier_name': 'Douglas Ltd',
#    'stock_quantity': 360,
#    'reorder_level': 67},
#   {'product_name': 'Growth Snack',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 257,
#    'reorder_level': 87},
#   {'product_name': 'Gun Device',
#    'supplier_name': 'Kaufman Ltd',
#    'stock_quantity': 556,
#    'reorder_level': 134},
#   {'product_name': 'Guy Device',
#    'supplier_name': 'Charles Inc',
#    'stock_quantity': 274,
#    'reorder_level': 93},
#   {'product_name': 'Hand Snack',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 233,
#    'reorder_level': 82},
#   {'product_name': 'Hard Snack',
#    'supplier_name': 'Evans Inc',
#    'stock_quantity': 79,
#    'reorder_level': 200},
#   {'product_name': 'Help Snack',
#    'supplier_name': 'Miller-Martinez',
#    'stock_quantity': 357,
#    'reorder_level': 142},
#   {'product_name': 'Himself Toy',
#    'supplier_name': 'Hall-Brown',
#    'stock_quantity': 347,
#    'reorder_level': 105},
#   {'product_name': 'Hold Toy',
#    'supplier_name': 'Mann-Marshall',
#    'stock_quantity': 695,
#    'reorder_level': 155},
#   {'product_name': 'Hospital Shirt',
#    'supplier_name': 'Hensley-Branch',
#    'stock_quantity': 444,
#    'reorder_level': 120},
#   {'product_name': 'However Snack',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 707,
#    'reorder_level': 95},
#   {'product_name': 'However Table',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 43,
#    'reorder_level': 52},
#   {'product_name': 'If Table',
#    'supplier_name': 'Mann-Marshall',
#    'stock_quantity': 393,
#    'reorder_level': 50},
#   {'product_name': 'Improve Snack',
#    'supplier_name': 'Lloyd and Sons',
#    'stock_quantity': 869,
#    'reorder_level': 181},
#   {'product_name': 'Include Device',
#    'supplier_name': 'Williams Ltd',
#    'stock_quantity': 856,
#    'reorder_level': 55},
#   {'product_name': 'Information Snack',
#    'supplier_name': 'Gallagher-Miller',
#    'stock_quantity': 708,
#    'reorder_level': 65},
#   {'product_name': 'Instead Snack',
#    'supplier_name': 'Freeman-Gordon',
#    'stock_quantity': 231,
#    'reorder_level': 51},
#   {'product_name': 'Instead Table',
#    'supplier_name': 'Elliott-Ayers',
#    'stock_quantity': 620,
#    'reorder_level': 99},
#   {'product_name': 'Investment Toy',
#    'supplier_name': 'Gallagher-Miller',
#    'stock_quantity': 834,
#    'reorder_level': 142},
#   {'product_name': 'Issue Device',
#    'supplier_name': 'Henderson LLC',
#    'stock_quantity': 412,
#    'reorder_level': 189},
#   {'product_name': 'Itself Shirt',
#    'supplier_name': 'Gallagher-Miller',
#    'stock_quantity': 133,
#    'reorder_level': 125},
#   {'product_name': 'Job Snack',
#    'supplier_name': 'Barrett Ltd',
#    'stock_quantity': 447,
#    'reorder_level': 120},
#   {'product_name': 'Just Device',
#    'supplier_name': 'Charles Inc',
#    'stock_quantity': 847,
#    'reorder_level': 114},
#   {'product_name': 'Later Toy',
#    'supplier_name': 'Tucker-Arnold',
#    'stock_quantity': 121,
#    'reorder_level': 61},
#   {'product_name': 'Law Device',
#    'supplier_name': 'Kaufman Ltd',
#    'stock_quantity': 485,
#    'reorder_level': 70},
#   {'product_name': 'Law Shirt',
#    'supplier_name': 'Ortega-Mahoney',
#    'stock_quantity': 675,
#    'reorder_level': 126},
#   {'product_name': 'Law Toy',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 931,
#    'reorder_level': 90},
#   {'product_name': 'Lead Toy',
#    'supplier_name': 'Gomez PLC',
#    'stock_quantity': 921,
#    'reorder_level': 156},
#   {'product_name': 'Least Table',
#    'supplier_name': 'Anderson-Thompson',
#    'stock_quantity': 58,
#    'reorder_level': 71},
#   {'product_name': 'Leave Device',
#    'supplier_name': 'Vega, Cook and Miller',
#    'stock_quantity': 521,
#    'reorder_level': 173},
#   {'product_name': 'Like Shirt',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'stock_quantity': 334,
#    'reorder_level': 131},
#   {'product_name': 'Local Shirt',
#    'supplier_name': 'Moss-Evans',
#    'stock_quantity': 749,
#    'reorder_level': 110},
#   {'product_name': 'Local Snack',
#    'supplier_name': 'Moss-Evans',
#    'stock_quantity': 861,
#    'reorder_level': 72},
#   {'product_name': 'Lose Toy',
#    'supplier_name': 'Mendoza-Jones',
#    'stock_quantity': 127,
#    'reorder_level': 92},
#   {'product_name': 'Manage Snack',
#    'supplier_name': 'Armstrong-Vance',
#    'stock_quantity': 63,
#    'reorder_level': 171},
#   {'product_name': 'Manage Table',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 328,
#    'reorder_level': 158},
#   {'product_name': 'Material Snack',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 451,
#    'reorder_level': 145},
#   {'product_name': 'Meet Shirt',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 892,
#    'reorder_level': 76},
#   {'product_name': 'Meeting Shirt',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 642,
#    'reorder_level': 143},
#   {'product_name': 'Member Toy',
#    'supplier_name': 'Hensley-Branch',
#    'stock_quantity': 516,
#    'reorder_level': 53},
#   {'product_name': 'Military Shirt',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'stock_quantity': 411,
#    'reorder_level': 110},
#   {'product_name': 'Mission Snack',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 893,
#    'reorder_level': 59},
#   {'product_name': 'Most Shirt',
#    'supplier_name': 'Freeman-Gordon',
#    'stock_quantity': 560,
#    'reorder_level': 93},
#   {'product_name': 'Mouth Shirt',
#    'supplier_name': 'Young, Browning and Ware',
#    'stock_quantity': 502,
#    'reorder_level': 99},
#   {'product_name': 'Movie Snack',
#    'supplier_name': 'Ortega-Mahoney',
#    'stock_quantity': 979,
#    'reorder_level': 131},
#   {'product_name': 'Mr Snack',
#    'supplier_name': 'Henderson LLC',
#    'stock_quantity': 944,
#    'reorder_level': 179},
#   {'product_name': 'National Shirt',
#    'supplier_name': 'Barrett Ltd',
#    'stock_quantity': 394,
#    'reorder_level': 198},
#   {'product_name': 'Necessary Device',
#    'supplier_name': 'Baxter-Meadows',
#    'stock_quantity': 298,
#    'reorder_level': 193},
#   {'product_name': 'Next Device',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 26,
#    'reorder_level': 200},
#   {'product_name': 'Nor Snack',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 122,
#    'reorder_level': 194},
#   {'product_name': 'North Shirt',
#    'supplier_name': 'Rowe PLC',
#    'stock_quantity': 644,
#    'reorder_level': 152},
#   {'product_name': 'Nothing Snack',
#    'supplier_name': 'Turner-Davis',
#    'stock_quantity': 375,
#    'reorder_level': 81},
#   {'product_name': 'Notice Toy',
#    'supplier_name': 'Evans Inc',
#    'stock_quantity': 640,
#    'reorder_level': 113},
#   {'product_name': 'Notice Toy',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 866,
#    'reorder_level': 60},
#   {'product_name': 'Old Shirt',
#    'supplier_name': 'Elliott-Ayers',
#    'stock_quantity': 996,
#    'reorder_level': 130},
#   {'product_name': 'Onto Shirt',
#    'supplier_name': 'Mann-Marshall',
#    'stock_quantity': 98,
#    'reorder_level': 62},
#   {'product_name': 'Paper Toy',
#    'supplier_name': 'Miller-Martinez',
#    'stock_quantity': 212,
#    'reorder_level': 101},
#   {'product_name': 'Part Device',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 652,
#    'reorder_level': 88},
#   {'product_name': 'Personal Table',
#    'supplier_name': 'Turner-Davis',
#    'stock_quantity': 962,
#    'reorder_level': 59},
#   {'product_name': 'Phone Shirt',
#    'supplier_name': 'Armstrong-Vance',
#    'stock_quantity': 97,
#    'reorder_level': 91},
#   {'product_name': 'Piece Device',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'stock_quantity': 536,
#    'reorder_level': 191},
#   {'product_name': 'Player Device',
#    'supplier_name': 'Newton, Valencia and Carr',
#    'stock_quantity': 530,
#    'reorder_level': 132},
#   {'product_name': 'Poor Snack',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 677,
#    'reorder_level': 143},
#   {'product_name': 'Race Device',
#    'supplier_name': 'Baxter-Meadows',
#    'stock_quantity': 108,
#    'reorder_level': 183},
#   {'product_name': 'Reach Device',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 623,
#    'reorder_level': 179},
#   {'product_name': 'Real Snack',
#    'supplier_name': 'Wong Group',
#    'stock_quantity': 4,
#    'reorder_level': 182},
#   {'product_name': 'Reality Table',
#    'supplier_name': 'Rowe PLC',
#    'stock_quantity': 804,
#    'reorder_level': 54},
#   {'product_name': 'Really Snack',
#    'supplier_name': 'Stewart, Williams and Cox',
#    'stock_quantity': 424,
#    'reorder_level': 160},
#   {'product_name': 'Region Toy',
#    'supplier_name': 'Wong Group',
#    'stock_quantity': 488,
#    'reorder_level': 68},
#   {'product_name': 'Report Toy',
#    'supplier_name': 'Hall-Brown',
#    'stock_quantity': 575,
#    'reorder_level': 166},
#   {'product_name': 'Require Toy',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 987,
#    'reorder_level': 102},
#   {'product_name': 'Return Table',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'stock_quantity': 39,
#    'reorder_level': 182},
#   {'product_name': 'Return Table',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 177,
#    'reorder_level': 75},
#   {'product_name': 'Run Device',
#    'supplier_name': 'Ortega-Mahoney',
#    'stock_quantity': 341,
#    'reorder_level': 111},
#   {'product_name': 'Scene Table',
#    'supplier_name': 'Freeman-Gordon',
#    'stock_quantity': 645,
#    'reorder_level': 74},
#   {'product_name': 'School Table',
#    'supplier_name': 'Douglas Ltd',
#    'stock_quantity': 687,
#    'reorder_level': 100},
#   {'product_name': 'Scientist Table',
#    'supplier_name': 'Franklin, Kane and Price',
#    'stock_quantity': 902,
#    'reorder_level': 114},
#   {'product_name': 'Security Shirt',
#    'supplier_name': 'Wilson, Graham and Williams',
#    'stock_quantity': 25,
#    'reorder_level': 70},
#   {'product_name': 'Sense Snack',
#    'supplier_name': 'Turner-Davis',
#    'stock_quantity': 675,
#    'reorder_level': 161},
#   {'product_name': 'Seven Table',
#    'supplier_name': 'Clark Group',
#    'stock_quantity': 649,
#    'reorder_level': 114},
#   {'product_name': 'Seven Table',
#    'supplier_name': 'Lawrence, Garcia and Hernandez',
#    'stock_quantity': 856,
#    'reorder_level': 120},
#   {'product_name': 'Several Snack',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 652,
#    'reorder_level': 199},
#   {'product_name': 'Sign Toy',
#    'supplier_name': 'Charles Inc',
#    'stock_quantity': 768,
#    'reorder_level': 169},
#   {'product_name': 'Simple Device',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 888,
#    'reorder_level': 77},
#   {'product_name': 'Since Shirt',
#    'supplier_name': 'Turner-Davis',
#    'stock_quantity': 304,
#    'reorder_level': 155},
#   {'product_name': 'Sit Toy',
#    'supplier_name': 'Williams Ltd',
#    'stock_quantity': 474,
#    'reorder_level': 121},
#   {'product_name': 'Six Device',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 493,
#    'reorder_level': 100},
#   {'product_name': 'Six Table',
#    'supplier_name': 'Douglas Ltd',
#    'stock_quantity': 442,
#    'reorder_level': 76},
#   {'product_name': 'SmartWatch',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'stock_quantity': 100,
#    'reorder_level': 25},
#   {'product_name': 'So Table',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 723,
#    'reorder_level': 60},
#   {'product_name': 'Someone Shirt',
#    'supplier_name': 'Hensley-Branch',
#    'stock_quantity': 801,
#    'reorder_level': 105},
#   {'product_name': 'Sound Snack',
#    'supplier_name': 'Hall-Brown',
#    'stock_quantity': 89,
#    'reorder_level': 59},
#   {'product_name': 'Sound Table',
#    'supplier_name': 'Morgan Inc',
#    'stock_quantity': 256,
#    'reorder_level': 84},
#   {'product_name': 'South Device',
#    'supplier_name': 'Hensley-Branch',
#    'stock_quantity': 742,
#    'reorder_level': 196},
#   {'product_name': 'Space Toy',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 693,
#    'reorder_level': 126},
#   {'product_name': 'Speak Shirt',
#    'supplier_name': 'Middleton LLC',
#    'stock_quantity': 540,
#    'reorder_level': 80},
#   {'product_name': 'Spring Toy',
#    'supplier_name': 'Vega, Cook and Miller',
#    'stock_quantity': 336,
#    'reorder_level': 199},
#   {'product_name': 'Staff Shirt',
#    'supplier_name': 'Rowland Ltd',
#    'stock_quantity': 191,
#    'reorder_level': 200},
#   {'product_name': 'Start Table',
#    'supplier_name': 'Barker, White and Carson',
#    'stock_quantity': 865,
#    'reorder_level': 147},
#   {'product_name': 'Still Snack',
#    'supplier_name': 'Rowland Ltd',
#    'stock_quantity': 433,
#    'reorder_level': 178},
#   {'product_name': 'Store Toy',
#    'supplier_name': 'Miller-Martinez',
#    'stock_quantity': 874,
#    'reorder_level': 50},
#   {'product_name': 'Story Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 510,
#    'reorder_level': 116},
#   {'product_name': 'Suddenly Device',
#    'supplier_name': 'Rogers-Greene',
#    'stock_quantity': 372,
#    'reorder_level': 183},
#   {'product_name': 'Suddenly Table',
#    'supplier_name': 'Patrick, Walter and Harrison',
#    'stock_quantity': 53,
#    'reorder_level': 166},
#   {'product_name': 'Summer Device',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 320,
#    'reorder_level': 96},
#   {'product_name': 'Sure Toy',
#    'supplier_name': 'Mann-Marshall',
#    'stock_quantity': 309,
#    'reorder_level': 125},
#   {'product_name': 'Surface Shirt',
#    'supplier_name': 'Vega, Cook and Miller',
#    'stock_quantity': 530,
#    'reorder_level': 137},
#   {'product_name': 'System Snack',
#    'supplier_name': 'Barker, White and Carson',
#    'stock_quantity': 503,
#    'reorder_level': 138},
#   {'product_name': 'Tax Device',
#    'supplier_name': 'Morgan Inc',
#    'stock_quantity': 644,
#    'reorder_level': 84},
#   {'product_name': 'Teacher Toy',
#    'supplier_name': 'Barrett Ltd',
#    'stock_quantity': 436,
#    'reorder_level': 189},
#   {'product_name': 'Thank Shirt',
#    'supplier_name': 'Barker, White and Carson',
#    'stock_quantity': 902,
#    'reorder_level': 83},
#   {'product_name': 'These Snack',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 998,
#    'reorder_level': 163},
#   {'product_name': 'This Snack',
#    'supplier_name': 'Tran LLC',
#    'stock_quantity': 20,
#    'reorder_level': 66},
#   {'product_name': 'Thought Toy',
#    'supplier_name': 'Stewart, Williams and Cox',
#    'stock_quantity': 147,
#    'reorder_level': 157},
#   {'product_name': 'Thought Toy',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 936,
#    'reorder_level': 133},
#   {'product_name': 'Throughout Snack',
#    'supplier_name': 'Williams Ltd',
#    'stock_quantity': 451,
#    'reorder_level': 57},
#   {'product_name': 'Throughout Snack',
#    'supplier_name': 'Henderson LLC',
#    'stock_quantity': 248,
#    'reorder_level': 118},
#   {'product_name': 'Throughout Toy',
#    'supplier_name': 'Wong Group',
#    'stock_quantity': 192,
#    'reorder_level': 118},
#   {'product_name': 'Throw Device',
#    'supplier_name': 'Young, Browning and Ware',
#    'stock_quantity': 862,
#    'reorder_level': 191},
#   {'product_name': 'Throw Toy',
#    'supplier_name': 'Morgan-Andrews',
#    'stock_quantity': 93,
#    'reorder_level': 155},
#   {'product_name': 'Tough Shirt',
#    'supplier_name': 'Gallagher-Miller',
#    'stock_quantity': 660,
#    'reorder_level': 154},
#   {'product_name': 'Town Toy',
#    'supplier_name': 'Morgan Inc',
#    'stock_quantity': 376,
#    'reorder_level': 182},
#   {'product_name': 'Treat Device',
#    'supplier_name': 'Smith, Kennedy and Moreno',
#    'stock_quantity': 122,
#    'reorder_level': 89},
#   {'product_name': 'Trouble Table',
#    'supplier_name': 'Moss-Evans',
#    'stock_quantity': 826,
#    'reorder_level': 166},
#   {'product_name': 'True Snack',
#    'supplier_name': 'Moody-Vang',
#    'stock_quantity': 741,
#    'reorder_level': 200},
#   {'product_name': 'Truth Device',
#    'supplier_name': 'Lloyd and Sons',
#    'stock_quantity': 570,
#    'reorder_level': 78},
#   {'product_name': 'Value Table',
#    'supplier_name': 'Douglas Ltd',
#    'stock_quantity': 480,
#    'reorder_level': 199},
#   {'product_name': 'Wait Toy',
#    'supplier_name': 'Mann-Marshall',
#    'stock_quantity': 164,
#    'reorder_level': 164},
#   {'product_name': 'Way Snack',
#    'supplier_name': 'Hall-Brown',
#    'stock_quantity': 725,
#    'reorder_level': 77},
#   {'product_name': 'Where Toy',
#    'supplier_name': 'Taylor-Love',
#    'stock_quantity': 848,
#    'reorder_level': 80},
#   {'product_name': 'White Table',
#    'supplier_name': 'Morgan-Andrews',
#    'stock_quantity': 702,
#    'reorder_level': 143},
#   {'product_name': 'Whom Table',
#    'supplier_name': 'Hudson Inc',
#    'stock_quantity': 727,
#    'reorder_level': 186},
#   {'product_name': 'Whose Snack',
#    'supplier_name': 'Wong Group',
#    'stock_quantity': 182,
#    'reorder_level': 177},
#   {'product_name': 'Within Toy',
#    'supplier_name': 'Harris-Cummings',
#    'stock_quantity': 839,
#    'reorder_level': 193},
#   {'product_name': 'Within Toy',
#    'supplier_name': 'Rogers-Greene',
#    'stock_quantity': 26,
#    'reorder_level': 189},
#   {'product_name': 'Writer Table',
#    'supplier_name': 'Anderson-Thompson',
#    'stock_quantity': 700,
#    'reorder_level': 198}],
#  'Product needing reorder': [{'product_id': 19,
#    'product_name': 'Next Device',
#    'stock_quantity': 26,
#    'reorder_level': 200},
#   {'product_id': 36,
#    'product_name': 'Race Device',
#    'stock_quantity': 108,
#    'reorder_level': 183},
#   {'product_id': 46,
#    'product_name': 'Close Toy',
#    'stock_quantity': 46,
#    'reorder_level': 161},
#   {'product_id': 50,
#    'product_name': 'Hard Snack',
#    'stock_quantity': 79,
#    'reorder_level': 200},
#   {'product_id': 51,
#    'product_name': 'Staff Shirt',
#    'stock_quantity': 191,
#    'reorder_level': 200},
#   {'product_id': 58,
#    'product_name': 'Floor Toy',
#    'stock_quantity': 67,
#    'reorder_level': 194},
#   {'product_id': 62,
#    'product_name': 'Throw Toy',
#    'stock_quantity': 93,
#    'reorder_level': 155},
#   {'product_id': 100,
#    'product_name': 'Fund Table',
#    'stock_quantity': 61,
#    'reorder_level': 112},
#   {'product_id': 108,
#    'product_name': 'Executive Table',
#    'stock_quantity': 38,
#    'reorder_level': 140},
#   {'product_id': 110,
#    'product_name': 'However Table',
#    'stock_quantity': 43,
#    'reorder_level': 52},
#   {'product_id': 113,
#    'product_name': 'Certain Device',
#    'stock_quantity': 10,
#    'reorder_level': 112},
#   {'product_id': 132,
#    'product_name': 'This Snack',
#    'stock_quantity': 20,
#    'reorder_level': 66},
#   {'product_id': 136,
#    'product_name': 'Within Toy',
#    'stock_quantity': 26,
#    'reorder_level': 189},
#   {'product_id': 137,
#    'product_name': 'Least Table',
#    'stock_quantity': 58,
#    'reorder_level': 71},
#   {'product_id': 144,
#    'product_name': 'Building Snack',
#    'stock_quantity': 4,
#    'reorder_level': 92},
#   {'product_id': 150,
#    'product_name': 'Return Table',
#    'stock_quantity': 39,
#    'reorder_level': 182},
#   {'product_id': 153,
#    'product_name': 'Security Shirt',
#    'stock_quantity': 25,
#    'reorder_level': 70},
#   {'product_id': 154,
#    'product_name': 'Manage Snack',
#    'stock_quantity': 63,
#    'reorder_level': 171},
#   {'product_id': 160,
#    'product_name': 'Suddenly Table',
#    'stock_quantity': 53,
#    'reorder_level': 166},
#   {'product_id': 165,
#    'product_name': 'Nor Snack',
#    'stock_quantity': 122,
#    'reorder_level': 194},
#   {'product_id': 167,
#    'product_name': 'Discuss Toy',
#    'stock_quantity': 117,
#    'reorder_level': 188},
#   {'product_id': 169,
#    'product_name': 'Four Shirt',
#    'stock_quantity': 63,
#    'reorder_level': 175},
#   {'product_id': 173,
#    'product_name': 'Real Snack',
#    'stock_quantity': 4,
#    'reorder_level': 182},
#   {'product_id': 180,
#    'product_name': 'Door Toy',
#    'stock_quantity': 11,
#    'reorder_level': 178},
#   {'product_id': 185,
#    'product_name': 'Couple Shirt',
#    'stock_quantity': 50,
#    'reorder_level': 138},
#   {'product_id': 192,
#    'product_name': 'Thought Toy',
#    'stock_quantity': 147,
#    'reorder_level': 157},
#   {'product_id': 199,
#    'product_name': 'Book Device',
#    'stock_quantity': 46,
#    'reorder_level': 66}]}

# %%
def add_new_manual_id(cursor, db, p_name, p_category, p_price, p_stock, p_reorder, p_supplier):
    proc_call = "call AddNewProductManualID(%s, %s, %s, %s, %s, %s)"
    params = (p_name, p_category, p_price, p_stock, p_reorder, p_supplier)
    cursor.execute(proc_call, params)
    db.commit()

# %%
def get_categories(cursor):
    cursor.execute("select distinct category from products order by category asc")
    rows = cursor.fetchall()
    return [row['category'] for row in rows]

# %%
get_categories(cursor)
# Out:
# ['Clothing', 'Electronics', 'Furniture', 'Groceries', 'Toys']

# %%
def get_suppliers(cursor):
    cursor.execute("select supplier_id, supplier_name from suppliers order by supplier_name asc")
    return cursor.fetchall()

# %%
suppliers = get_suppliers(cursor)

# %%
supplier_ids = [s['supplier_id'] for s in suppliers]
supplier_names = [s['supplier_name'] for s in suppliers]

f = lambda x: supplier_names[supplier_ids.index(x)]

# %%
result = [f(x) for x in supplier_ids]
print(result)
# Out:
# ['Anderson-Thompson', 'Armstrong-Vance', 'Barker, White and Carson', 'Barrett Ltd', 'Baxter-Meadows', 'Charles Inc', 'Clark Group', 'Douglas Ltd', 'Elliott-Ayers', 'Evans Inc', 'Franklin, Kane and Price', 'Freeman-Gordon', 'Gallagher-Miller', 'Gomez PLC', 'Hall-Brown', 'Harris-Cummings', 'Henderson LLC', 'Hensley-Branch', 'Hudson Inc', 'Johnson-Bass', 'Kaufman Ltd', 'Lawrence, Garcia and Hernandez', 'Lloyd and Sons', 'Mann-Marshall', 'Mendoza-Jones', 'Middleton LLC', 'Miller-Martinez', 'Moody-Vang', 'Morgan Inc', 'Morgan-Andrews', 'Moss-Evans', 'Newton, Valencia and Carr', 'Ortega-Mahoney', 'Patrick, Walter and Harrison', 'Perez, Price and Wallace', 'Reynolds-Phillips', 'Rogers-Greene', 'Rowe PLC', 'Rowland Ltd', 'Smith, Kennedy and Moreno', 'Stewart, Williams and Cox', 'Taylor-Love', 'Tran LLC', 'Tucker-Arnold', 'Turner-Davis', 'Vega, Cook and Miller', 'Williams Ltd', 'Wilson, Graham and Williams', 'Wong Group', 'Young, Browning and Ware']
